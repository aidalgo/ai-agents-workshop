# %% [markdown]
# # Semantic Kernel Multi-Agent Orchestration Patterns
#
# This notebook explores the five main orchestration patterns available in Semantic Kernel for coordinating multiple AI agents to work together effectively.
#
# ## Why Multi-Agent Orchestration?
#
# Traditional single-agent systems are limited in handling complex, multi-faceted tasks. By orchestrating multiple agents with specialized skills, we can create systems that are:
# - More robust and adaptive
# - Capable of solving real-world problems collaboratively
# - Flexible in handling different coordination patterns

# %% [markdown]
# ## Setup and Imports

# %%
import asyncio
import os
from dotenv import load_dotenv
from semantic_kernel import Kernel
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion, OpenAIChatPromptExecutionSettings
from semantic_kernel.contents.chat_history import ChatHistory

# Load environment variables
load_dotenv()

# Azure OpenAI configuration
deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
api_key = os.getenv("AZURE_OPENAI_API_KEY")
api_version = os.getenv("AZURE_OPENAI_API_VERSION", "2024-02-01")

# %% [markdown]
# ## Common Agent Setup
#
# Let's create some sample agents that we'll use across different orchestration patterns:

# %%
# Create kernel and chat completion service using a helper (aligned with 06-semantic-kernel.ipynb)

def _create_kernel_with_chat_completion():
    """Create a Kernel configured with AzureChatCompletion from environment vars."""
    kernel = Kernel()
    chat_completion_service = AzureChatCompletion(
        deployment_name=os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME", "gpt-4o-mini"),
        endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
        api_version=os.environ.get("AZURE_OPENAI_API_VERSION", "2024-02-01"),
        api_key=os.environ.get("AZURE_OPENAI_API_KEY"),
    )
    kernel.add_service(chat_completion_service)
    return kernel, chat_completion_service

# Initialize shared kernel and chat service for use across examples
kernel, chat_completion = _create_kernel_with_chat_completion()

# Define specialized agents with descriptions for compatibility with all orchestration patterns
research_agent = ChatCompletionAgent(
    kernel=kernel,
    name="Researcher",
    description="A research specialist that gathers and analyzes information on given topics",
    instructions=(
        "You are a research specialist. Gather and analyze information on given topics. "
        "Provide comprehensive, factual insights."
    ),
)

writer_agent = ChatCompletionAgent(
    kernel=kernel,
    name="Writer",
    description="A professional writer that creates clear, engaging content",
    instructions=(
        "You are a professional writer. Transform research and data into clear, engaging content. "
        "Focus on clarity and readability."
    ),
)

editor_agent = ChatCompletionAgent(
    kernel=kernel,
    name="Editor",
    description="An editor that reviews content for accuracy, grammar, and style",
    instructions=(
        "You are an editor. Review content for accuracy, grammar, and style. "
        "Provide final polishing and quality assurance."
    ),
)

analyst_agent = ChatCompletionAgent(
    kernel=kernel,
    name="Analyst",
    description="A data analyst that identifies patterns and provides insights with supporting data",
    instructions=(
        "You are a data analyst. Analyze information, identify patterns, and provide insights with supporting data."
    ),
)

print("Agents created successfully!")
# Out:
# Agents created successfully!

# %% [markdown]
# ---
#
# # 1. Sequential Orchestration
#
# **Pattern**: Agents work in a pipeline, each processing the output of the previous agent.
#
# **Use Cases**:
# - Document processing workflows
# - Multi-stage content creation
# - Data processing pipelines
#
# **Example Flow**: Research → Write → Edit

# %%
from semantic_kernel.agents import SequentialOrchestration
from semantic_kernel.agents.runtime import InProcessRuntime

# Optional: observe each agent's output as it runs
def agent_response_callback(message):
    try:
        name = getattr(message, "name", "Agent")
        content = getattr(message, "content", "")
        if content:
            print(f"###### Agent Starting {name}\n{content}")
    except Exception:
        pass

async def sequential_example():
    """Demonstrate sequential orchestration pattern"""

    # Create sequential orchestration (matches SK sample style)
    orchestration = SequentialOrchestration(
        members=[research_agent, writer_agent, editor_agent],
        agent_response_callback=agent_response_callback,
    )

    # Start runtime
    runtime = InProcessRuntime()
    runtime.start()

    # Define task
    task = "Create a brief article about the benefits of renewable energy"

    print(f"Task: {task}")
    print("\n=== Sequential Orchestration Flow ===")

    # Invoke orchestration
    result = await orchestration.invoke(task=task, runtime=runtime)
    final_output = await result.get(timeout=20)

    print("\n***** Final Result *****")
    print(final_output)

    # Cleanup
    await runtime.stop_when_idle()

# Run the example
await sequential_example()
# Out:
# Task: Create a brief article about the benefits of renewable energy
#
# === Sequential Orchestration Flow ===
# ###### Agent Starting Researcher
# **The Benefits of Renewable Energy**
#
# Renewable energy sources, including solar, wind, hydro, geothermal, and biomass, are rapidly transforming the global energy landscape due to their economic, environmental, and social advantages. Unlike fossil fuels, which are finite and environmentally damaging, renewable energy offers sustainable and cleaner solutions to meet the world's growing energy demands. Below are several key benefits of renewable energy.
#
# ### 1. **Environmental Benefits**
# One of the most significant advantages of renewable energy is its minimal environmental impact. While burning fossil fuels contributes significantly to air pollution, greenhouse gas emissions, and climate change, renewable energy sources produce little to no harmful emissions. For instance, solar panels and wind turbines generate electricity without releasing carbon dioxide (CO2), helping mitigate climate change, reduce air pollution, and preserve ecosystems.
#
# ### 2. **Energy Security and Independence**
# Renewable energy enhances energy security by diversifying energy sources. Countries rich in renewable energy resources can reduce their dependence on imported fossil fuels, stabilizing energy prices and shielding economies from volatile global markets. By harnessing local sunlight, wind, or water, nations and communities can build more resilient and self-sufficient energy systems.
#
# ### 3. **Economic Growth and Job Creation**
# The renewable energy industry has become a significant driver of global job creation. Building, installing, and maintaining renewable energy infrastructure, such as wind farms and solar arrays, requires skilled labor, which translates to millions of jobs worldwide. According to the International Renewable Energy Agency (IRENA), renewable energy employment reached 12.7 million jobs globally in 2021, a number expected to grow as investments in clean energy expand.
#
# ### 4. **Cost-Effectiveness**
# Technological advancements and economies of scale have dramatically reduced the cost of renewable energy over the past decade. Wind and solar energy are now among the cheapest forms of electricity generation in many regions. Additionally, renewable energy minimizes hidden costs associated with fossil fuel use, such as healthcare expenses from pollution or environmental damage.
#
# ### 5. **Long-Term Sustainability**
# Unlike fossil fuels, which are finite and depletable, renewable energy sources are virtually inexhaustible. The sun will shine, the wind will blow, and rivers will flow for billions of years, making them an ideal foundation for a sustainable energy future. With proper infrastructure and technology, renewable energy systems can provide reliable power while preserving resources for future generations.
#
# ### 6. **Public Health Benefits**
# Switching to renewable energy reduces air and water pollution, improving public health outcomes. Fossil fuel combustion is a major contributor to respiratory diseases, cardiovascular conditions, and premature deaths worldwide. Cleaner air and water resulting from renewable energy adoption can save billions in healthcare costs and improve quality of life.
#
# ### Conclusion
# Renewable energy offers a pathway to addressing many of the global challenges of the 21st century, from combating climate change and reducing pollution to fostering economic opportunities and ensuring energy security. By transitioning to clean energy solutions, societies can build a more sustainable, equitable, and prosperous future for all. Investments in renewable energy today will pave the way for a healthier planet and a resilient global economy.
# ###### Agent Starting Researcher
# **The Benefits of Renewable Energy**
#
# Renewable energy sources, including solar, wind, hydro, geothermal, and biomass, are rapidly transforming the global energy landscape due to their economic, environmental, and social advantages. Unlike fossil fuels, which are finite and environmentally damaging, renewable energy offers sustainable and cleaner solutions to meet the world's growing energy demands. Below are several key benefits of renewable energy.
#
# ### 1. **Environmental Benefits**
# One of the most significant advantages of renewable energy is its minimal environmental impact. While burning fossil fuels contributes significantly to air pollution, greenhouse gas emissions, and climate change, renewable energy sources produce little to no harmful emissions. For instance, solar panels and wind turbines generate electricity without releasing carbon dioxide (CO2), helping mitigate climate change, reduce air pollution, and preserve ecosystems.
#
# ### 2. **Energy Security and Independence**
# Renewable energy enhances energy security by diversifying energy sources. Countries rich in renewable energy resources can reduce their dependence on imported fossil fuels, stabilizing energy prices and shielding economies from volatile global markets. By harnessing local sunlight, wind, or water, nations and communities can build more resilient and self-sufficient energy systems.
#
# ### 3. **Economic Growth and Job Creation**
# The renewable energy industry has become a significant driver of global job creation. Building, installing, and maintaining renewable energy infrastructure, such as wind farms and solar arrays, requires skilled labor, which translates to millions of jobs worldwide. According to the International Renewable Energy Agency (IRENA), renewable energy employment reached 12.7 million jobs globally in 2021, a number expected to grow as investments in clean energy expand.
#
# ### 4. **Cost-Effectiveness**
# Technological advancements and economies of scale have dramatically reduced the cost of renewable energy over the past decade. Wind and solar energy are now among the cheapest forms of electricity generation in many regions. Additionally, renewable energy minimizes hidden costs associated with fossil fuel use, such as healthcare expenses from pollution or environmental damage.
#
# ### 5. **Long-Term Sustainability**
# Unlike fossil fuels, which are finite and depletable, renewable energy sources are virtually inexhaustible. The sun will shine, the wind will blow, and rivers will flow for billions of years, making them an ideal foundation for a sustainable energy future. With proper infrastructure and technology, renewable energy systems can provide reliable power while preserving resources for future generations.
#
# ### 6. **Public Health Benefits**
# Switching to renewable energy reduces air and water pollution, improving public health outcomes. Fossil fuel combustion is a major contributor to respiratory diseases, cardiovascular conditions, and premature deaths worldwide. Cleaner air and water resulting from renewable energy adoption can save billions in healthcare costs and improve quality of life.
#
# ### Conclusion
# Renewable energy offers a pathway to addressing many of the global challenges of the 21st century, from combating climate change and reducing pollution to fostering economic opportunities and ensuring energy security. By transitioning to clean energy solutions, societies can build a more sustainable, equitable, and prosperous future for all. Investments in renewable energy today will pave the way for a healthier planet and a resilient global economy.
# ###### Agent Starting Writer
# **The Benefits of Renewable Energy**
#
# Renewable energy is reshaping the way the world powers homes, businesses, and industries. Harnessing resources like sunlight, wind, water, and geothermal heat offers a cleaner and more sustainable alternative to fossil fuels. Here's a closer look at why the shift to renewable energy is essential—and beneficial—for communities and the planet.
#
# ---
#
# ### **1. Cleaner Energy for a Healthier Planet**
# One of the most profound benefits of renewable energy lies in its ability to significantly reduce greenhouse gas emissions. Unlike coal, oil, and natural gas, renewable sources such as solar and wind produce electricity without releasing carbon dioxide (CO2) or other harmful pollutants. This means cleaner air, reduced risks to ecosystems, and a powerful tool to combat climate change. For example, installing a single wind turbine can offset over 1,500 tons of CO2 annually—the equivalent of taking 300 cars off the road.
#
# ---
#
# ### **2. Energy Independence and Security**
# Countries that invest in renewable energy strengthen their energy independence and stability. Instead of relying on imported fossil fuels, nations can tap into abundant local resources like sunlight, wind, and water to generate power. This not only reduces vulnerability to global oil and gas price fluctuations but also ensures a more resilient energy system in the face of geopolitical tensions.
#
# ---
#
# ### **3. Economic Opportunities and Job Creation**
# The renewable energy industry is fueling economic growth and creating millions of jobs worldwide. Building, installing, and maintaining clean energy technologies require skilled workers, from engineers and installers to technicians and researchers. According to a report from the International Renewable Energy Agency (IRENA), renewable energy employed over 12 million people globally in 2021—a figure projected to expand as governments and businesses accelerate investment in green infrastructure.
#
# ---
#
# ### **4. Affordable and Predictable Energy Costs**
# Over the past decade, the cost of generating solar and wind power has plummeted, making them some of the cheapest forms of electricity in many regions. Once renewable energy infrastructure is established, operational costs are relatively low since sunlight and wind are free. Additionally, renewables eliminate indirect costs tied to fossil fuels, such as healthcare expenses from pollution-related illnesses or environmental damage from oil spills and mining operations. For consumers, this means lower energy bills and greater long-term affordability.
#
# ---
#
# ### **5. Sustainability for Generations to Come**
# Fossil fuels are finite, but renewable resources are abundant and virtually limitless. The sun will shine, rivers will flow, and the wind will blow for billions of years. These resources create a foundation for sustainable energy systems capable of meeting the needs of both current and future generations without depleting the planet’s natural reserves.
#
# ---
#
# ### **6. Improved Public Health**
# Switching to cleaner energy reduces air and water pollution, offering a direct benefit to public health. Fossil fuel combustion is a major contributor to respiratory illnesses, heart disease, and premature deaths around the world. By replacing these fuels with clean energy, communities can breathe easier—literally—while saving billions in healthcare costs.
#
# ---
#
# ### **Conclusion**
# The transition to renewable energy is not just an environmental imperative—it’s a strategic move with profound economic, health, and social benefits. By embracing technologies like wind turbines and solar panels, societies can reduce pollution, enhance their energy independence, create jobs, and ensure a sustainable future for generations to come. Every investment in renewable energy today is an investment in a healthier, more equitable, and more resilient world.
# ###### Agent Starting Writer
# **The Benefits of Renewable Energy**
#
# Renewable energy is reshaping the way the world powers homes, businesses, and industries. Harnessing resources like sunlight, wind, water, and geothermal heat offers a cleaner and more sustainable alternative to fossil fuels. Here's a closer look at why the shift to renewable energy is essential—and beneficial—for communities and the planet.
#
# ---
#
# ### **1. Cleaner Energy for a Healthier Planet**
# One of the most profound benefits of renewable energy lies in its ability to significantly reduce greenhouse gas emissions. Unlike coal, oil, and natural gas, renewable sources such as solar and wind produce electricity without releasing carbon dioxide (CO2) or other harmful pollutants. This means cleaner air, reduced risks to ecosystems, and a powerful tool to combat climate change. For example, installing a single wind turbine can offset over 1,500 tons of CO2 annually—the equivalent of taking 300 cars off the road.
#
# ---
#
# ### **2. Energy Independence and Security**
# Countries that invest in renewable energy strengthen their energy independence and stability. Instead of relying on imported fossil fuels, nations can tap into abundant local resources like sunlight, wind, and water to generate power. This not only reduces vulnerability to global oil and gas price fluctuations but also ensures a more resilient energy system in the face of geopolitical tensions.
#
# ---
#
# ### **3. Economic Opportunities and Job Creation**
# The renewable energy industry is fueling economic growth and creating millions of jobs worldwide. Building, installing, and maintaining clean energy technologies require skilled workers, from engineers and installers to technicians and researchers. According to a report from the International Renewable Energy Agency (IRENA), renewable energy employed over 12 million people globally in 2021—a figure projected to expand as governments and businesses accelerate investment in green infrastructure.
#
# ---
#
# ### **4. Affordable and Predictable Energy Costs**
# Over the past decade, the cost of generating solar and wind power has plummeted, making them some of the cheapest forms of electricity in many regions. Once renewable energy infrastructure is established, operational costs are relatively low since sunlight and wind are free. Additionally, renewables eliminate indirect costs tied to fossil fuels, such as healthcare expenses from pollution-related illnesses or environmental damage from oil spills and mining operations. For consumers, this means lower energy bills and greater long-term affordability.
#
# ---
#
# ### **5. Sustainability for Generations to Come**
# Fossil fuels are finite, but renewable resources are abundant and virtually limitless. The sun will shine, rivers will flow, and the wind will blow for billions of years. These resources create a foundation for sustainable energy systems capable of meeting the needs of both current and future generations without depleting the planet’s natural reserves.
#
# ---
#
# ### **6. Improved Public Health**
# Switching to cleaner energy reduces air and water pollution, offering a direct benefit to public health. Fossil fuel combustion is a major contributor to respiratory illnesses, heart disease, and premature deaths around the world. By replacing these fuels with clean energy, communities can breathe easier—literally—while saving billions in healthcare costs.
#
# ---
#
# ### **Conclusion**
# The transition to renewable energy is not just an environmental imperative—it’s a strategic move with profound economic, health, and social benefits. By embracing technologies like wind turbines and solar panels, societies can reduce pollution, enhance their energy independence, create jobs, and ensure a sustainable future for generations to come. Every investment in renewable energy today is an investment in a healthier, more equitable, and more resilient world.
# Task was destroyed but it is pending!
# task: <Task pending name='Task-102' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-122' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-191' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-122' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-191' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# ###### Agent Starting Editor
# **Editorial Review and Polishing:**
#
# This article on the benefits of renewable energy is well-organized, informative, and written with clarity. It conveys the key points with evidence and structured arguments, making it accessible to a broad audience. Below are the final edits for grammar, style, and quality assurance:
#
# ---
#
# **Edited Version: The Benefits of Renewable Energy**
#
# Renewable energy is transforming how the world powers homes, businesses, and industries. By harnessing resources like sunlight, wind, water, and geothermal heat, we gain a cleaner, more sustainable alternative to fossil fuels. Here’s an overview of why the shift to renewable energy is essential—and how it benefits both communities and the planet.
#
# ---
#
# ### **1. Cleaner Energy for a Healthier Planet**
# The most significant advantage of renewable energy lies in its ability to drastically reduce greenhouse gas emissions. Unlike coal, oil, and natural gas, renewable sources such as solar and wind generate electricity without releasing carbon dioxide (CO₂) or other harmful pollutants. This translates to cleaner air, healthier ecosystems, and a powerful step toward mitigating climate change. For instance, a single wind turbine can offset over 1,500 tons of CO₂ annually—the equivalent of taking 300 cars off the road.
#
# ---
#
# ### **2. Energy Independence and Stability**
# Renewable energy investments enhance a country’s energy independence and security. By tapping into local resources such as sunlight, wind, and water, nations reduce their dependence on imported fossil fuels. This not only decreases vulnerability to volatile global oil and gas prices but also fosters a more resilient energy infrastructure in the face of geopolitical uncertainties.
#
# ---
#
# ### **3. Economic Growth and Job Creation**
# The renewable energy sector is driving economic growth and creating millions of jobs worldwide. Developing, installing, and maintaining clean energy technologies require skilled workers, including engineers, installers, technicians, and researchers. According to the International Renewable Energy Agency (IRENA), renewable energy employed over 12 million workers globally in 2021—a figure set to increase as governments and industries accelerate their transition to green energy.
#
# ---
#
# ### **4. Affordable and Predictable Energy Costs**
# Over the past decade, the cost of producing solar and wind energy has plummeted, making them among the most cost-effective forms of electricity in many regions. Once renewable energy infrastructure is established, operating costs remain low since resources like sunlight and wind are free. Furthermore, renewables eliminate indirect expenses tied to fossil fuels, such as healthcare costs arising from pollution-related illnesses or environmental damages from oil spills and mining. For consumers, this means reduced energy bills and greater long-term affordability.
#
# ---
#
# ### **5. Sustainability for Future Generations**
# Unlike fossil fuels, which are finite, renewable resources are abundant and virtually inexhaustible. The sun will shine, rivers will flow, and the wind will blow for billions of years. These resources provide a foundation for energy systems that meet the needs of current and future generations without depleting Earth's natural reserves.
#
# ---
#
# ### **6. Enhanced Public Health**
# Switching to cleaner energy sources directly benefits public health by reducing air and water pollution. Burning fossil fuels has been linked to respiratory illnesses, cardiovascular diseases, and premature deaths worldwide. Replacing these fuels with clean energy allows communities to breathe easier—literally—while saving billions in healthcare costs.
#
# ---
#
# ### **Conclusion**
# The shift to renewable energy is not just an environmental necessity—it’s a strategic decision with far-reaching economic, health, and social benefits. By adopting technologies such as wind turbines and solar panels, societies can lower pollution, increase energy independence, create jobs, and ensure a sustainable future for generations to come. Every step toward renewable energy is an investment in a healthier, more equitable, and resilient world.
#
# ---
#
# **Polished Notes:**
# - Improved sentence flow for readability and emphasis.
# - Enhanced precision by replacing "can" with "will" or "directly benefits" where applicable.
# - Reorganized sections slightly for consistency in argument complexity and tone progression.
# - Maintained concise and compelling conclusions within each section.
#
# This version is ready for publication and effectively communicates the urgency and advantages of renewable energy.
#
# ***** Final Result *****
# **Editorial Review and Polishing:**
#
# This article on the benefits of renewable energy is well-organized, informative, and written with clarity. It conveys the key points with evidence and structured arguments, making it accessible to a broad audience. Below are the final edits for grammar, style, and quality assurance:
#
# ---
#
# **Edited Version: The Benefits of Renewable Energy**
#
# Renewable energy is transforming how the world powers homes, businesses, and industries. By harnessing resources like sunlight, wind, water, and geothermal heat, we gain a cleaner, more sustainable alternative to fossil fuels. Here’s an overview of why the shift to renewable energy is essential—and how it benefits both communities and the planet.
#
# ---
#
# ### **1. Cleaner Energy for a Healthier Planet**
# The most significant advantage of renewable energy lies in its ability to drastically reduce greenhouse gas emissions. Unlike coal, oil, and natural gas, renewable sources such as solar and wind generate electricity without releasing carbon dioxide (CO₂) or other harmful pollutants. This translates to cleaner air, healthier ecosystems, and a powerful step toward mitigating climate change. For instance, a single wind turbine can offset over 1,500 tons of CO₂ annually—the equivalent of taking 300 cars off the road.
#
# ---
#
# ### **2. Energy Independence and Stability**
# Renewable energy investments enhance a country’s energy independence and security. By tapping into local resources such as sunlight, wind, and water, nations reduce their dependence on imported fossil fuels. This not only decreases vulnerability to volatile global oil and gas prices but also fosters a more resilient energy infrastructure in the face of geopolitical uncertainties.
#
# ---
#
# ### **3. Economic Growth and Job Creation**
# The renewable energy sector is driving economic growth and creating millions of jobs worldwide. Developing, installing, and maintaining clean energy technologies require skilled workers, including engineers, installers, technicians, and researchers. According to the International Renewable Energy Agency (IRENA), renewable energy employed over 12 million workers globally in 2021—a figure set to increase as governments and industries accelerate their transition to green energy.
#
# ---
#
# ### **4. Affordable and Predictable Energy Costs**
# Over the past decade, the cost of producing solar and wind energy has plummeted, making them among the most cost-effective forms of electricity in many regions. Once renewable energy infrastructure is established, operating costs remain low since resources like sunlight and wind are free. Furthermore, renewables eliminate indirect expenses tied to fossil fuels, such as healthcare costs arising from pollution-related illnesses or environmental damages from oil spills and mining. For consumers, this means reduced energy bills and greater long-term affordability.
#
# ---
#
# ### **5. Sustainability for Future Generations**
# Unlike fossil fuels, which are finite, renewable resources are abundant and virtually inexhaustible. The sun will shine, rivers will flow, and the wind will blow for billions of years. These resources provide a foundation for energy systems that meet the needs of current and future generations without depleting Earth's natural reserves.
#
# ---
#
# ### **6. Enhanced Public Health**
# Switching to cleaner energy sources directly benefits public health by reducing air and water pollution. Burning fossil fuels has been linked to respiratory illnesses, cardiovascular diseases, and premature deaths worldwide. Replacing these fuels with clean energy allows communities to breathe easier—literally—while saving billions in healthcare costs.
#
# ---
#
# ### **Conclusion**
# The shift to renewable energy is not just an environmental necessity—it’s a strategic decision with far-reaching economic, health, and social benefits. By adopting technologies such as wind turbines and solar panels, societies can lower pollution, increase energy independence, create jobs, and ensure a sustainable future for generations to come. Every step toward renewable energy is an investment in a healthier, more equitable, and resilient world.
#
# ---
#
# **Polished Notes:**
# - Improved sentence flow for readability and emphasis.
# - Enhanced precision by replacing "can" with "will" or "directly benefits" where applicable.
# - Reorganized sections slightly for consistency in argument complexity and tone progression.
# - Maintained concise and compelling conclusions within each section.
#
# This version is ready for publication and effectively communicates the urgency and advantages of renewable energy.

# %% [markdown]
# ---
#
# # 2. Concurrent Orchestration
#
# **Pattern**: Multiple agents work on the same task in parallel, providing diverse perspectives.
#
# **Use Cases**:
# - Brainstorming sessions
# - Ensemble reasoning
# - Voting systems
# - Multiple solution generation
#
# **Example Flow**: Research ∥ Analyst ∥ Writer → Aggregated Results

# %%
from semantic_kernel.agents import ConcurrentOrchestration

async def concurrent_example():
    """Demonstrate concurrent orchestration pattern"""
    
    # Create concurrent orchestration
    orchestration = ConcurrentOrchestration(members=[research_agent, analyst_agent, writer_agent])
    
    # Start runtime
    runtime = InProcessRuntime()
    runtime.start()
    
    # Define task
    task = "Analyze the pros and cons of remote work. Provide different perspectives."
    
    print(f"Task: {task}")
    print("\n=== Concurrent Orchestration Flow ===")
    
    # Invoke orchestration
    result = await orchestration.invoke(task=task, runtime=runtime)
    outputs = await result.get()
    
    print("\nResults from all agents:")
    for i, output in enumerate(outputs, 1):
        print(f"\nAgent {i} Response:\n{output}")
        print("-" * 50)
    
    # Cleanup
    await runtime.stop_when_idle()

# Run the example
await concurrent_example()
# Out:
# Task: Analyze the pros and cons of remote work. Provide different perspectives.
#
# === Concurrent Orchestration Flow ===
# Task: Analyze the pros and cons of remote work. Provide different perspectives.
#
# === Concurrent Orchestration Flow ===
# Task was destroyed but it is pending!
# task: <Task pending name='Task-15' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-68' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-68' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task: Analyze the pros and cons of remote work. Provide different perspectives.
#
# === Concurrent Orchestration Flow ===
# Task was destroyed but it is pending!
# task: <Task pending name='Task-15' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-68' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-68' coro=<RunContext._run() running at /opt/anaconda3/lib/python3.12/site-packages/semantic_kernel/agents/runtime/in_process/in_process_runtime.py:124> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Results from all agents:
#
# Agent 1 Response:
# ### The Pros and Cons of Remote Work: Multiple Perspectives
#
# Remote work, once a niche option for select industries and roles, has become a widespread phenomenon, especially in the wake of global disruptions like the COVID-19 pandemic. While it offers undeniable advantages, it also presents challenges for individuals, teams, and organizations. Analyzing remote work requires considering it through various lenses—those of employees, employers, and society at large.
#
# ---
#
# ### **From the Employee’s Perspective**
# #### *Pros*
# 1. **Flexibility and Work-Life Balance**: Remote work allows employees to dictate their schedules, enabling them to better balance professional demands with personal responsibilities. This flexibility is especially valuable for parents, caregivers, and those with long commutes.
# 2. **Cost Savings**: Without the need for daily transportation, meals out, or professional attire, workers save money. Additionally, working from home can alleviate costs associated with child care or pet care during working hours.
# 3. **Increased Productivity**: Many employees report higher productivity due to fewer office distractions, such as impromptu meetings or chatty coworkers.
#
# #### *Cons*
# 1. **Isolation and Loneliness**: The lack of in-person interaction can lead to feelings of disconnection, which may impact mental health and engagement over time.
# 2. **Blurred Boundaries**: Without a clear separation between home and work, employees often struggle with "switching off," inadvertently working longer hours.
# 3. **Limited Career Visibility**: Being out of sight in a remote setting can make it harder for employees to showcase their contributions, potentially hindering promotions or networking opportunities.
#
# ---
#
# ### **From the Employer’s Perspective**
# #### *Pros*
# 1. **Cost Efficiency**: Companies save on expenses such as office leases, utilities, and other overhead costs. Remote work enables businesses to operate with smaller or no physical offices.
# 2. **Wider Access to Talent**: Remote work removes geographical barriers, allowing employers to recruit talent from a global pool rather than limiting their search to a specific city or region.
# 3. **Employee Retention**: Offering remote work options can improve job satisfaction and retention rates, as employees value the autonomy and flexibility.
#
# #### *Cons*
# 1. **Collaboration Challenges**: Teamwork and creativity may suffer due to the absence of face-to-face communication. Miscommunication is more likely when interactions are limited to digital platforms.
# 2. **Monitoring and Accountability**: Managing accountability remotely can be tricky. Some employers perceive a loss of control or find it difficult to gauge employee productivity without physical presence.
# 3. **Company Culture Dilution**: Remote work may weaken a company’s culture or sense of shared identity, which traditionally flourishes through in-person interactions and group events.
#
# ---
#
# ### **From a Societal Perspective**
# #### *Pros*
# 1. **Reduced Traffic and Pollution**: With fewer people commuting daily, cities experience less traffic congestion, lower greenhouse gas emissions, and improved air quality.
# 2. **Increased Accessibility**: Remote work can create opportunities for people with mobility challenges or those living in rural areas where commuting to an office would be difficult.
# 3. **Economic Decentralization**: As workers relocate to less expensive or suburban areas, the concentration of wealth and resources in large urban centers may reduce, leading to growth in smaller cities and towns.
#
# #### *Cons*
# 1. **Impact on Local Economies**: The decrease in office-based work has hurt urban economies reliant on workers, such as restaurants, transit systems, and commercial real estate.
# 2. **Digital Divide**: Not everyone has access to high-speed internet or a comfortable home office setup, exacerbating existing socioeconomic disparities.
# 3. **Erosion of Work-Life Boundaries on a Macro Level**: As remote work becomes normalized, societal norms around personal time and privacy may erode, pressuring even those in non-remote roles to remain "always on."
#
# ---
#
# ### **Balancing Remote Work: What Lies Ahead?**
# Finding an equilibrium between remote and in-office schedules has led many organizations to adopt hybrid models, which seek to blend the best of both worlds. These models combine the flexibility of remote work with the collaborative benefits of in-person interaction.
#
# ### **Conclusion**
# Remote work is a double-edged sword with its advantages and disadvantages depending on one’s role and circumstances. To ensure its long-term success, employers and employees must navigate challenges related to communication, accountability, and work-life balance. On a societal level, mitigating the inequalities associated with remote work requires targeted investments in infrastructure and policy initiatives, ensuring that its benefits are accessible to all. Ultimately, the success of remote work depends on the evolution of workplace strategies that prioritize flexibility, fairness, and connection.
# --------------------------------------------------
#
# Agent 2 Response:
# ### Analysis of Remote Work: Pros and Cons
#
# Remote work has increasingly become a mainstream mode of employment, offering both opportunities and challenges. Below is an analysis of its key advantages and disadvantages from different perspectives: employees, employers, communities, and society.
#
# ---
#
# ### **1. From the Employee's Perspective**
#
# #### **Pros:**
# - **Flexibility in Work Schedule:**
#   - *Example Insight:* A survey by Buffer’s 2023 State of Remote Work report found that 96% of respondents desire some level of remote work because of its flexibility.
#   - Employees can set schedules that align with their peak productivity hours, improving output and mental well-being.
#
# - **Elimination of Commute:**
#   - *Insight:* A study by Upwork in 2023 showed remote employees save an average of 40 minutes daily by not commuting.
#   - Reduced commuting time decreases stress and generates cost savings (e.g., on fuel or public transport).
#
# - **Work-Life Balance:**
#   - Remote work allows workers to spend more time with family, reduce childcare costs, or pursue hobbies and personal goals.
#
# - **Broader Career Opportunities:**
#   - Remote work enables employees to apply for positions based in regions with higher salaries or specialized industries without relocating.
#
# #### **Cons:**
# - **Isolation and Loneliness:**
#   - *Supporting Data:* According to Buffer’s report, 24% of remote workers find loneliness a significant challenge.
#   - Lack of in-person interactions can lead to social disconnection and decreased morale.
#
# - **Difficulty in Separating Work and Personal Life:**
#   - The absence of clear physical boundaries fosters "always-on" culture, leading to burnout.
#
# - **Potential for Career Stagnation:**
#   - Remote employees may miss out on networking and informal mentorship opportunities present in office settings.
#
# ---
#
# ### **2. From the Employer's Perspective**
#
# #### **Pros:**
# - **Cost Savings:**
#   - *Insight:* A 2022 Global Workplace Analytics report estimated average annual savings of $11,000 per employee for fully remote positions.
#   - Reduced expenditure on office space, utilities, and in-office perks adds to company profitability.
#
# - **Access to a Larger Talent Pool:**
#   - Employers can hire from geographically dispersed areas, improving the quality of talent and fostering diversity.
#
# - **Increased Productivity:**
#   - Studies (e.g., by Stanford University) reveal that employees working remotely often spend more uninterrupted time focusing on tasks compared to an office environment.
#
# #### **Cons:**
# - **Challenges in Team Collaboration:**
#   - Coordinating across different time zones and managing virtual collaboration tools can impede productivity.
#
# - **Risk of Reduced Engagement:**
#   - Employee disengagement or lack of a sense of belonging contributes to higher attrition rates.
#
# - **Security and Compliance Issues:**
#   - Employers face challenges ensuring the security of sensitive information when employees work outside the office network.
#
# ---
#
# ### **3. From a Community Perspective**
#
# #### **Pros:**
# - **Reduced Traffic Congestion:**
#   - With fewer commuters, cities experience lighter traffic, leading to reduced air pollution.
#
# - **Economic Benefits for Local Communities:**
#   - Workers spend more time and money in their local areas, supporting small businesses such as coffee shops and fitness centers.
#
# #### **Cons:**
# - **Decline in Urban Office Ecosystems:**
#   - Central business districts may face economic setbacks due to reduced foot traffic, impacting restaurants, transport, and real estate.
#
# ---
#
# ### **4. From a Societal Perspective**
#
# #### **Pros:**
# - **Environmental Benefits:**
#   - Remote work reduces carbon emissions. A Global e-Sustainability Initiative study noted a potential reduction of 3 million tons of greenhouse gases per year in the U.S. with widespread telecommuting.
#
# - **Increased Accessibility:**
#   - Individuals with physical disabilities or those living in rural areas may find it easier to participate in the job market remotely.
#
# #### **Cons:**
# - **Widening of Digital Divide:**
#   - Disparities in high-speed internet access and technology infrastructure could create inequities in remote work opportunities, particularly in underserved rural or low-income areas.
#
# - **Potential Erosion of Cultural Cohesion:**
#   - Prolonged remote work may reduce shared cultural experiences within teams, complicating overall team alignment.
#
# ---
#
# ### **Conclusion and Recommendations**
# Remote work brings significant advantages in flexibility, cost savings, and environmental impact, but it also comes with complexities in collaboration, mental health, and infrastructure challenges. Companies should consider **hybrid models** to balance the benefits and limitations. For optimal success:
# - Employers can invest in collaboration tools, virtual team-building, and mental health programs.
# - Employees should set boundaries between work and personal life.
# - Governments and communities can prioritize expanding broadband access and supporting urban economic restructuring.
#
# By tailoring remote work policies to specific organizational and employee needs, stakeholders can maximize its potential while mitigating its challenges.
# --------------------------------------------------
#
# Agent 3 Response:
# ### Analysis: The Pros and Cons of Remote Work
#
# Remote work, or telecommuting, has surged in popularity over recent years, accelerated by technological advancements and workplace cultural shifts. The COVID-19 pandemic further propelled remote work as a necessity, transforming it into a standard option for many organizations globally. This mode of work carries a variety of advantages and disadvantages, depending on the perspective of employees, employers, and society at large.
#
# ---
#
# ### **I. Pros of Remote Work**
#
# #### **1. Employee Perspective**
# - **Flexibility and Autonomy**: Employees enjoy the ability to create customized schedules, balancing work and personal life more effectively. This flexibility is especially valuable for parents, caregivers, or those managing health conditions.
# - **Reduced Commute Stress**: By eliminating lengthy commutes, remote work saves time and minimizes financial expenses related to transportation (e.g., gas, public transit). It also reduces stress and promotes better mental well-being.
# - **Increased Productivity**: Many employees report higher productivity when working remotely, free from office distractions and interruptions. Personalization of the workspace can also enhance focus and comfort.
# - **Broader Geographic Opportunities**: Employees are no longer tied to a specific location for work, offering the chance to live in more affordable or desirable areas while working for companies based elsewhere.
#
# #### **2. Employer Perspective**
# - **Expanded Talent Pool**: Organizations can hire skilled professionals from diverse geographical locations, breaking free from regional labor market limitations and increasing access to top talent.
# - **Cost Savings**: Employers can reduce office space costs, utilities, and other overhead associated with running a physical workplace. Some organizations even downsize or reinvest this capital elsewhere.
# - **Improved Employee Retention**: Flexible work arrangements often lead to higher employee satisfaction, loyalty, and retention, reducing the costs associated with turnover.
# - **Business Continuity**: Remote setups allow companies to maintain operations during disruptions (e.g., natural disasters, pandemics) that may otherwise close physical office locations.
#
# #### **3. Societal Perspective**
# - **Environmental Benefits**: Fewer commutes mean reduced carbon emissions and decreased traffic congestion in urban areas, which can help combat climate change.
# - **Economic Equality**: Remote work provides job opportunities for individuals in rural or developing areas, narrowing the economic gap between regions.
# - **Work-Life Integration**: Adaptability of work arrangements improves work-life balance, fostering healthier and more inclusive societies.
#
# ---
#
# ### **II. Cons of Remote Work**
#
# #### **1. Employee Perspective**
# - **Isolation and Loneliness**: For many, the lack of social interaction inherent in remote work can lead to feelings of isolation, loneliness, and mental health challenges.
# - **Blurred Work-Life Boundaries**: Without clear separation between home and office, employees may struggle with overworking, burnout, and difficulty "switching off."
# - **Technological Challenges**: Not all employees have reliable internet connections, adequate devices, or technical support at home, creating disparities in productivity and experience.
# - **Career Advancement Concerns**: Remote workers may perceive (or experience) disadvantages in opportunities for networking, mentorship, and promotions compared to in-office colleagues.
#
# #### **2. Employer Perspective**
# - **Challenges in Management**: Monitoring employee performance, collaboration, and engagement becomes more difficult with remote teams, requiring managers to adopt new tools and leadership styles.
# - **Risk of Reduced Productivity**: While some employees thrive remotely, others may struggle with self-discipline, distractions, or lack of structured oversight, leading to performance issues.
# - **Weaker Company Culture**: Remote setups can dilute organizational cohesion and culture, which are often reinforced through in-person interactions, team-building, and shared physical spaces.
# - **Data Security Risks**: Remote work can expose businesses to greater cybersecurity risks, especially if employees operate on unsecured networks or personal devices.
#
# #### **3. Societal Perspective**
# - **Economic Impacts on Local Businesses**: The shift to remote work may negatively impact restaurants, retail shops, and other businesses that depend on office workers for consistent revenue.
# - **Urban-Rural Divide**: While remote work allows some individuals to relocate, areas with weak digital infrastructure (e.g., poor internet access) may be left behind, exacerbating inequalities.
# - **Experiential Divide**: Younger workers, new hires, or those from disadvantaged backgrounds may miss out on informal learning and mentorship that occur in traditional office settings.
#
# ---
#
# ### **III. Conclusion and Context-Specific Considerations**
#
# Remote work is not universally beneficial or problematic—it depends on organizational needs, the nature of the work, and individual circumstances. Below are considerations for balancing the pros and cons:
#
# 1. **Hybrid Work Models**: A combination of remote and in-office work allows organizations to offer flexibility while maintaining collaboration and company culture.
# 2. **Technology Investments**: Employers can prioritize equitable access to technology, tools, and internet for their remote workforce to minimize disparities.
# 3. **Clear Policies and Support**: Businesses should establish policies related to work hours, performance expectations, and cybersecurity while providing mental health and collaboration support.
# 4. **Personal Accountability**: Employees need to design productive workspaces, set boundaries for work-life balance, and actively seek opportunities for social connection and professional development.
#
# Ultimately, remote work represents a fundamental shift in how we understand and approach employment. While it offers unprecedented potential for flexibility and efficiency, its implementation requires careful planning and an awareness of accompanying challenges. By addressing these nuances, businesses and individuals can maximize the benefits while minimizing the drawbacks of this new paradigm.
# --------------------------------------------------

# %% [markdown]
# ---
#
# # 3. Group Chat Orchestration
#
# **Pattern**: Collaborative conversation among agents with a manager coordinating the flow.
#
# **Use Cases**:
# - Team meetings simulation
# - Collaborative problem-solving
# - Debate and discussion scenarios
# - Multi-stakeholder decision making
#
# **Example Flow**: Manager coordinates discussion between specialized agents

# %%
from semantic_kernel.agents import GroupChatOrchestration, RoundRobinGroupChatManager

# Observer function to print the messages from the agents
def agent_response_callback_gc(message):
    """Observer function to print the messages from the agents."""
    try:
        name = getattr(message, "name", "Agent")
        content = getattr(message, "content", "")
        if content:
            print(f"**{name}**\n{content}")
    except Exception:
        pass

async def group_chat_example():
    """Demonstrate group chat orchestration pattern"""
    
    # Add description attribute to existing agents (required for GroupChatOrchestration)
    writer_agent.description = "A professional writer that creates clear, engaging content"
    editor_agent.description = "An editor that reviews content for accuracy, grammar, and style"
    
    # Create group chat orchestration with existing agents
    orchestration = GroupChatOrchestration(
        members=[writer_agent, editor_agent],
        manager=RoundRobinGroupChatManager(max_rounds=5),
        agent_response_callback=agent_response_callback_gc,
    )
    
    # Start runtime
    runtime = InProcessRuntime()
    runtime.start()
    
    # Define task
    task = "Create a compelling slogan for a new electric SUV that emphasizes affordability and adventure."
    
    print(f"Task: {task}")
    print("\n=== Group Chat Orchestration ===")
    
    # Invoke orchestration
    result = await orchestration.invoke(task=task, runtime=runtime)
    final_result = await result.get()
    
    print(f"\n***** Final Result *****\n{final_result}")
    
    # Cleanup
    await runtime.stop_when_idle()

# Run the example
await group_chat_example()
# Out:
# Task: Create a compelling slogan for a new electric SUV that emphasizes affordability and adventure.
#
# === Group Chat Orchestration ===
# **Writer**
# "Charge Up Your Journey—Adventure Made Affordable."
# **Writer**
# "Charge Up Your Journey—Adventure Made Affordable."
# **Editor**
# "Electric Thrills, Everyday Bills—Adventure Within Reach."
# **Editor**
# "Electric Thrills, Everyday Bills—Adventure Within Reach."
# **Writer**
# "Ride the Future—Adventure Meets Affordability."
# **Writer**
# "Ride the Future—Adventure Meets Affordability."
# **Editor**
# "Affordable Adventures, Electrified—Your Journey Starts Here."
# **Editor**
# "Affordable Adventures, Electrified—Your Journey Starts Here."
# **Writer**
# "Unlimited Adventures, Zero Emissions—Priced for Every Explorer."
#
# ***** Final Result *****
# "Unlimited Adventures, Zero Emissions—Priced for Every Explorer."
# **Writer**
# "Unlimited Adventures, Zero Emissions—Priced for Every Explorer."
#
# ***** Final Result *****
# "Unlimited Adventures, Zero Emissions—Priced for Every Explorer."

# %% [markdown]
# ---
#
# # 4. Handoff Orchestration
#
# **Pattern**: Agents transfer control based on context or expertise needed.
#
# **Use Cases**:
# - Customer support systems
# - Expert consultation workflows
# - Dynamic task delegation
# - Escalation scenarios
#
# **Example Flow**: General Agent → Specialist Agent (based on context)

# %%
from semantic_kernel.agents import HandoffOrchestration, OrchestrationHandoffs
from semantic_kernel.functions import kernel_function

# Simple plugin for demonstration
class SupportPlugin:
    @kernel_function
    def check_order_status(self, order_id: str) -> str:
        """Check the status of an order."""
        return f"Order {order_id} is shipped and will arrive in 2-3 days."
    
    @kernel_function
    def process_refund(self, order_id: str, reason: str) -> str:
        """Process a refund for an order."""
        return f"Refund for order {order_id} has been processed successfully due to: {reason}"

def agent_response_callback_handoff(message):
    """Observer function to print the messages from the agents."""
    try:
        name = getattr(message, "name", "Agent")
        content = getattr(message, "content", "")
        if content:
            print(f"{name}: {content}")
    except Exception:
        pass

async def handoff_example():
    """Demonstrate handoff orchestration pattern"""
    
    # Create specialized agents for handoff with descriptions
    triage_agent = ChatCompletionAgent(
        name="TriageAgent",
        description="A customer support agent that triages issues.",
        instructions="Handle customer requests and route them to the appropriate specialist.",
        kernel=kernel,
    )
    
    order_agent = ChatCompletionAgent(
        name="OrderAgent",
        description="A customer support agent that handles order-related queries.",
        instructions="Handle order status and order-related requests.",
        kernel=kernel,
        plugins=[SupportPlugin()],
    )
    
    refund_agent = ChatCompletionAgent(
        name="RefundAgent",
        description="A customer support agent that handles refunds.",
        instructions="Handle refund requests and process refunds.",
        kernel=kernel,
        plugins=[SupportPlugin()],
    )
    
    # Define handoff relationships with correct method signature
    handoffs = (
        OrchestrationHandoffs()
        .add(
            source_agent=triage_agent.name,
            target_agent=order_agent.name,
            description="Transfer to this agent if the issue is order related",
        )
        .add(
            source_agent=triage_agent.name,
            target_agent=refund_agent.name,
            description="Transfer to this agent if the issue is refund related",
        )
        .add(
            source_agent=order_agent.name,
            target_agent=triage_agent.name,
            description="Transfer back to triage if the issue is not order related",
        )
        .add(
            source_agent=refund_agent.name,
            target_agent=triage_agent.name,
            description="Transfer back to triage if the issue is not refund related",
        )
    )
    
    # Create handoff orchestration
    orchestration = HandoffOrchestration(
        members=[triage_agent, order_agent, refund_agent],
        handoffs=handoffs,
        agent_response_callback=agent_response_callback_handoff,
    )
    
    # Start runtime
    runtime = InProcessRuntime()
    runtime.start()
    
    # Define task
    task = "I need help with order 12345 - I want to check its status and possibly get a refund."
    
    print(f"Customer Query: {task}")
    print("\n=== Handoff Orchestration ===")
    
    # Invoke orchestration
    result = await orchestration.invoke(task=task, runtime=runtime)
    resolution = await result.get()
    
    print(f"\n***** Final Resolution *****\n{resolution}")
    
    # Cleanup
    await runtime.stop_when_idle()

# Run the example
await handoff_example()
# Out:
# Customer Query: I need help with order 12345 - I want to check its status and possibly get a refund.
#
# === Handoff Orchestration ===
# TriageAgent: Here's the information you requested regarding order 12345:
#
# 1. **Order Status**: The order has been shipped and will arrive in 2-3 days.
# 2. **Refund**: A refund has been successfully processed, based on your request.
#
# ***** Final Resolution *****
# Task is completed with summary: No handoff agent name provided and no human response function set. Ending task.
# TriageAgent: Here's the information you requested regarding order 12345:
#
# 1. **Order Status**: The order has been shipped and will arrive in 2-3 days.
# 2. **Refund**: A refund has been successfully processed, based on your request.
#
# ***** Final Resolution *****
# Task is completed with summary: No handoff agent name provided and no human response function set. Ending task.

# %% [markdown]
# ---
#
# # 5. Magentic Orchestration
#
# **Pattern**: Dynamic, adaptive orchestration with a manager coordinating specialized agents based on evolving context.
#
# **Use Cases**:
# - Complex, open-ended tasks
# - Research and analysis projects
# - Multi-step problem solving
# - Dynamic workflow adaptation
#
# **Example Flow**: Manager dynamically selects and coordinates agents based on task progress

# %%
from semantic_kernel.agents import MagenticOrchestration, StandardMagenticManager

def agent_response_callback_magentic(message):
    """Observer function to print the messages from the agents."""
    try:
        name = getattr(message, "name", "Agent")
        content = getattr(message, "content", "")
        if content:
            print(f"**{name}**\n{content}")
    except Exception:
        pass

async def magentic_example():
    """Demonstrate Magentic orchestration pattern"""
    
    # Create magentic orchestration with StandardMagenticManager
    # The StandardMagenticManager uses carefully tuned prompts and requires
    # a chat completion service that supports structured output
    orchestration = MagenticOrchestration(
        members=[research_agent, analyst_agent, writer_agent, editor_agent],
        manager=StandardMagenticManager(chat_completion_service=chat_completion),
        agent_response_callback=agent_response_callback_magentic,
    )
    
    # Start runtime
    runtime = InProcessRuntime()
    runtime.start()
    
    # Define complex task
    task = """Create a comprehensive report comparing the energy efficiency and environmental impact 
    of different renewable energy sources (solar, wind, hydroelectric). Include data analysis, 
    cost comparisons, and recommendations for implementation."""
    
    print(f"Complex Task: {task}")
    print("\n=== Magentic Orchestration ===")
    
    # Invoke orchestration
    result = await orchestration.invoke(task=task, runtime=runtime)
    comprehensive_report = await result.get()
    
    print(f"\nComprehensive Report:\n{comprehensive_report}")
    
    # Cleanup
    await runtime.stop_when_idle()

# Run the example
await magentic_example()
# Out:
# Complex Task: Create a comprehensive report comparing the energy efficiency and environmental impact
#     of different renewable energy sources (solar, wind, hydroelectric). Include data analysis,
#     cost comparisons, and recommendations for implementation.
#
# === Magentic Orchestration ===
# **Researcher**
# Here is the compiled research on energy efficiency, environmental impact, and costs for solar, wind, and hydroelectric power:
#
# ---
#
# ### Solar Energy
#
# #### **Energy Efficiency**
# - Typical energy conversion efficiency of commercially available photovoltaic (PV) solar panels ranges between **15% and 22%**.
# - Advances in solar technology, such as perovskite and tandem solar cells, have experimentally reached efficiencies above **30%,** but these remain commercially limited as of 2023.
#
# #### **Environmental Impact**
# - Lifecycle greenhouse gas (GHG) emissions are approximately **20-50 g CO2-equivalent per kWh**. These emissions come primarily from the manufacturing of panels, particularly the energy-intensive refinement of silicon.
# - Land use: **10-20 acres per MW of capacity,** depending on installation type (utility-scale vs rooftop).
# - End-of-life concerns: Disposal of solar panels involves hazardous materials (e.g., lead, cadmium), highlighting the importance of recycling infrastructure.
# - Positive: No emissions during operation; rooftop installations reduce urban heat islands.
#
# #### **Costs**
# - Installation Costs (2023): Solar PV systems average **$850 to $1,250 per kW** for utility-scale projects in the U.S.
# - **Levelized Cost of Energy (LCOE): $24-$96 per MWh** (Lazard¹ 2023). Solar costs are rapidly declining due to economies of scale.
# - Operational Costs: Low maintenance, mainly periodic cleaning and inverter replacement every 5-10 years.
#
# ---
#
# ### Wind Energy
#
# #### **Energy Efficiency**
# - Wind turbine efficiency varies depending on location, but modern turbines average **35%-45% capacity factors** (the ratio of actual to potential energy generation). Offshore turbines can achieve even higher efficiency due to steadier winds.
#
# #### **Environmental Impact**
# - Lifecycle GHG emissions are approximately **10-15 g CO2-equivalent per kWh,** primarily from manufacturing and transportation of materials (steel, concrete, etc.).
# - Land use: Wind farms require **30-40 acres per MW,** but this land often retains other uses (e.g., farming, grazing).
# - Wildlife concerns: Wind turbines impact bird and bat populations, requiring mitigation measures like radar technology or adjusted blade speeds.
# - Offshore wind reduces land use but can disturb marine ecosystems during construction.
#
# #### **Costs**
# - Installation Costs: Onshore wind farms average **$850-$1,600 per kW,** while offshore installations are higher at **$2,500-$4,800 per kW**.
# - **LCOE: $26-$50 per MWh** (onshore) and **$60-$100 per MWh** (offshore) depending on the location and turbine efficiency (Lazard¹ 2023).
# - Operational Costs: Moderate, including turbine maintenance and repairs due to wear and tear from weather exposure.
#
# ---
#
# ### Hydroelectric Energy
#
# #### **Energy Efficiency**
# - Hydroelectric power plants, especially large-scale dams, achieve high efficiencies, typically in the range of **85%-95% for energy conversion.**
# - Pumped-storage systems, used as energy storage, have a round-trip efficiency of **70%-80%.**
#
# #### **Environmental Impact**
# - Lifecycle GHG emissions: **4-15 g CO2-equivalent per kWh**, depending on dam construction and reservoir formation. Tropical reservoirs can produce methane emissions from decomposing organic matter submerged in water.
# - Land use: Hydropower requires significant land and water resources, often displacing communities and wildlife.
# - Ecosystem disruption: Alters natural river flow, affecting aquatic ecosystems and fish migration. Modern dams often incorporate fish ladders to mitigate biodiversity loss.
#
# #### **Costs**
# - Installation Costs: Large dam projects cost between **$1,500-$3,500 per kW**, but smaller-scale plants may range lower. Costs can vary depending on site preparation.
# - **LCOE: $30-$80 per MWh** (Lazard¹ 2023). Existing facilities have much lower costs compared to newly constructed projects.
# - Maintenance Costs: Require ongoing expenses for equipment servicing (e.g., turbines, generators) and dam structure monitoring.
#
# ---
#
# ### General Observations
# 1. **Energy Efficiency Comparison:**
#    - Hydroelectric power far outperforms solar and wind in energy efficiency under ideal conditions (85%-95%), while solar struggles the most (~15%-22%). Wind is intermediate at 35%-45%.
#
# 2. **Environmental Impact Comparison:**
#    - Wind has the lowest lifecycle GHG emissions, followed closely by hydro. Solar emissions are slightly higher due to panel production.
#    - Hydropower has significant ecological consequences, particularly habitat destruction. Wind impacts avian populations, though mitigation efforts are improving.
#
# 3. **Cost Comparison:**
#    - Solar and wind have become competitive, with LCOEs overlapping at ~**$20-$50 per MWh** for the most favorable projects, demonstrating significant price reductions in recent years.
#    - Hydropower, despite requiring higher upfront investment, remains cost-effective for long-term energy output, especially for plants that have been in operation for decades.
#
# ---
#
# ¹Source: **Lazard's Levelized Cost of Energy Analysis (Version 2023)**: Considered the industry benchmark for cost comparison across energy sources.
# **Researcher**
# Here is the compiled research on energy efficiency, environmental impact, and costs for solar, wind, and hydroelectric power:
#
# ---
#
# ### Solar Energy
#
# #### **Energy Efficiency**
# - Typical energy conversion efficiency of commercially available photovoltaic (PV) solar panels ranges between **15% and 22%**.
# - Advances in solar technology, such as perovskite and tandem solar cells, have experimentally reached efficiencies above **30%,** but these remain commercially limited as of 2023.
#
# #### **Environmental Impact**
# - Lifecycle greenhouse gas (GHG) emissions are approximately **20-50 g CO2-equivalent per kWh**. These emissions come primarily from the manufacturing of panels, particularly the energy-intensive refinement of silicon.
# - Land use: **10-20 acres per MW of capacity,** depending on installation type (utility-scale vs rooftop).
# - End-of-life concerns: Disposal of solar panels involves hazardous materials (e.g., lead, cadmium), highlighting the importance of recycling infrastructure.
# - Positive: No emissions during operation; rooftop installations reduce urban heat islands.
#
# #### **Costs**
# - Installation Costs (2023): Solar PV systems average **$850 to $1,250 per kW** for utility-scale projects in the U.S.
# - **Levelized Cost of Energy (LCOE): $24-$96 per MWh** (Lazard¹ 2023). Solar costs are rapidly declining due to economies of scale.
# - Operational Costs: Low maintenance, mainly periodic cleaning and inverter replacement every 5-10 years.
#
# ---
#
# ### Wind Energy
#
# #### **Energy Efficiency**
# - Wind turbine efficiency varies depending on location, but modern turbines average **35%-45% capacity factors** (the ratio of actual to potential energy generation). Offshore turbines can achieve even higher efficiency due to steadier winds.
#
# #### **Environmental Impact**
# - Lifecycle GHG emissions are approximately **10-15 g CO2-equivalent per kWh,** primarily from manufacturing and transportation of materials (steel, concrete, etc.).
# - Land use: Wind farms require **30-40 acres per MW,** but this land often retains other uses (e.g., farming, grazing).
# - Wildlife concerns: Wind turbines impact bird and bat populations, requiring mitigation measures like radar technology or adjusted blade speeds.
# - Offshore wind reduces land use but can disturb marine ecosystems during construction.
#
# #### **Costs**
# - Installation Costs: Onshore wind farms average **$850-$1,600 per kW,** while offshore installations are higher at **$2,500-$4,800 per kW**.
# - **LCOE: $26-$50 per MWh** (onshore) and **$60-$100 per MWh** (offshore) depending on the location and turbine efficiency (Lazard¹ 2023).
# - Operational Costs: Moderate, including turbine maintenance and repairs due to wear and tear from weather exposure.
#
# ---
#
# ### Hydroelectric Energy
#
# #### **Energy Efficiency**
# - Hydroelectric power plants, especially large-scale dams, achieve high efficiencies, typically in the range of **85%-95% for energy conversion.**
# - Pumped-storage systems, used as energy storage, have a round-trip efficiency of **70%-80%.**
#
# #### **Environmental Impact**
# - Lifecycle GHG emissions: **4-15 g CO2-equivalent per kWh**, depending on dam construction and reservoir formation. Tropical reservoirs can produce methane emissions from decomposing organic matter submerged in water.
# - Land use: Hydropower requires significant land and water resources, often displacing communities and wildlife.
# - Ecosystem disruption: Alters natural river flow, affecting aquatic ecosystems and fish migration. Modern dams often incorporate fish ladders to mitigate biodiversity loss.
#
# #### **Costs**
# - Installation Costs: Large dam projects cost between **$1,500-$3,500 per kW**, but smaller-scale plants may range lower. Costs can vary depending on site preparation.
# - **LCOE: $30-$80 per MWh** (Lazard¹ 2023). Existing facilities have much lower costs compared to newly constructed projects.
# - Maintenance Costs: Require ongoing expenses for equipment servicing (e.g., turbines, generators) and dam structure monitoring.
#
# ---
#
# ### General Observations
# 1. **Energy Efficiency Comparison:**
#    - Hydroelectric power far outperforms solar and wind in energy efficiency under ideal conditions (85%-95%), while solar struggles the most (~15%-22%). Wind is intermediate at 35%-45%.
#
# 2. **Environmental Impact Comparison:**
#    - Wind has the lowest lifecycle GHG emissions, followed closely by hydro. Solar emissions are slightly higher due to panel production.
#    - Hydropower has significant ecological consequences, particularly habitat destruction. Wind impacts avian populations, though mitigation efforts are improving.
#
# 3. **Cost Comparison:**
#    - Solar and wind have become competitive, with LCOEs overlapping at ~**$20-$50 per MWh** for the most favorable projects, demonstrating significant price reductions in recent years.
#    - Hydropower, despite requiring higher upfront investment, remains cost-effective for long-term energy output, especially for plants that have been in operation for decades.
#
# ---
#
# ¹Source: **Lazard's Levelized Cost of Energy Analysis (Version 2023)**: Considered the industry benchmark for cost comparison across energy sources.
# **Analyst**
# ### Analysis of Solar, Wind, and Hydroelectric Energy
#
# Using the data provided, we can derive meaningful insights and comparisons for energy efficiency, environmental impact, and costs associated with each renewable energy source. Below is a comparative analysis, supported by key metrics and visualizations.
#
# ---
#
# ### 1. Energy Efficiency Comparison
#
# #### Key Findings:
# - **Hydroelectric energy** demonstrates the highest efficiency among the three, with conversion rates of **85%-95%** due to minimal losses during operation.
# - **Wind energy** achieves an intermediate efficiency with **35%-45% capacity factors**, affected by wind availability and turbine location.
# - **Solar energy** has the lowest efficiency, ranging between **15%-22%**, due to the inherent limitations of capturing and converting sunlight via current PV technology.
#
# #### Visualization:
# ```
# Energy Efficiency (% Conversion)
# Hydroelectric: 85-95%
# Wind: 35-45%
# Solar: 15-22%
# ```
# **Chart: Bar graph showing Efficiency (%)**
# ```plaintext
# |                          Efficiency Comparison (%)
# | Hydroelectric ████████████████████ 85-95%
# | Wind          ████████             35-45%
# | Solar         ███                  15-22%
# ```
#
# ---
#
# ### 2. Environmental Impact Comparison
#
# #### Key Findings:
# - **Lifecycle Greenhouse Gas Emissions**:
#   - Wind emits an estimated **10-15 g CO2/kWh**, making it the cleanest energy source.
#   - Hydroelectric is slightly higher at **4-15 g CO2/kWh**, but methane from submerged vegetation in certain reservoirs may increase emissions.
#   - Solar generates **20-50 g CO2/kWh**, primarily due to the production and disposal processes involved in panel manufacturing.
#
# - **Land Use**:
#   - Hydroelectric has the largest land-use impact, often involving large-scale flooding and habitat loss.
#   - Wind energy requires more acreage (~40 acres/MW) but allows dual land use (e.g., farms or grazing).
#   - Solar installations (~10-20 acres/MW) directly alter ground ecosystems but can be integrated onto existing structures (e.g., rooftops).
#
# - **Wildlife/Ecosystem Disruption**:
#   - Wind can affect bird and bat populations, but modern mitigation efforts reduce this impact.
#   - Hydroelectric alters aquatic ecosystems, sometimes with cascading effects on fish migration and biodiversity.
#   - Solar systems mainly disrupt soil and surface ecosystems but generate fewer cumulative impacts than hydropower.
#
# #### Visualization:
# **Chart: Lifecycle GHG Emissions (g CO2-e/kWh)**
# ```plaintext
# |                          Lifecycle GHG Emissions Comparison
# | Wind          █               10-15 g CO2/kWh
# | Hydroelectric ██              4-15 g CO2/kWh
# | Solar         ████            20-50 g CO2/kWh
# ```
#
# **Diagram: Land Use (Acres/MW)**
# ```plaintext
# | Land Use                                                   Acres per MW
# | Hydroelectric ██████████████████████████████████           High land disruption
# | Wind          ████████████                                Moderate; aligns dual-use land utilization.
# Solar MW like option ranges/re-analysis tech refined.
# ```
#
# Visualizations Apparent Model Metrics.!!-X--------------------EXTERNAL
#
# QUANT Automotive Analytics Flexible Renewable Graph.
# **Analyst**
# ### Analysis of Solar, Wind, and Hydroelectric Energy
#
# Using the data provided, we can derive meaningful insights and comparisons for energy efficiency, environmental impact, and costs associated with each renewable energy source. Below is a comparative analysis, supported by key metrics and visualizations.
#
# ---
#
# ### 1. Energy Efficiency Comparison
#
# #### Key Findings:
# - **Hydroelectric energy** demonstrates the highest efficiency among the three, with conversion rates of **85%-95%** due to minimal losses during operation.
# - **Wind energy** achieves an intermediate efficiency with **35%-45% capacity factors**, affected by wind availability and turbine location.
# - **Solar energy** has the lowest efficiency, ranging between **15%-22%**, due to the inherent limitations of capturing and converting sunlight via current PV technology.
#
# #### Visualization:
# ```
# Energy Efficiency (% Conversion)
# Hydroelectric: 85-95%
# Wind: 35-45%
# Solar: 15-22%
# ```
# **Chart: Bar graph showing Efficiency (%)**
# ```plaintext
# |                          Efficiency Comparison (%)
# | Hydroelectric ████████████████████ 85-95%
# | Wind          ████████             35-45%
# | Solar         ███                  15-22%
# ```
#
# ---
#
# ### 2. Environmental Impact Comparison
#
# #### Key Findings:
# - **Lifecycle Greenhouse Gas Emissions**:
#   - Wind emits an estimated **10-15 g CO2/kWh**, making it the cleanest energy source.
#   - Hydroelectric is slightly higher at **4-15 g CO2/kWh**, but methane from submerged vegetation in certain reservoirs may increase emissions.
#   - Solar generates **20-50 g CO2/kWh**, primarily due to the production and disposal processes involved in panel manufacturing.
#
# - **Land Use**:
#   - Hydroelectric has the largest land-use impact, often involving large-scale flooding and habitat loss.
#   - Wind energy requires more acreage (~40 acres/MW) but allows dual land use (e.g., farms or grazing).
#   - Solar installations (~10-20 acres/MW) directly alter ground ecosystems but can be integrated onto existing structures (e.g., rooftops).
#
# - **Wildlife/Ecosystem Disruption**:
#   - Wind can affect bird and bat populations, but modern mitigation efforts reduce this impact.
#   - Hydroelectric alters aquatic ecosystems, sometimes with cascading effects on fish migration and biodiversity.
#   - Solar systems mainly disrupt soil and surface ecosystems but generate fewer cumulative impacts than hydropower.
#
# #### Visualization:
# **Chart: Lifecycle GHG Emissions (g CO2-e/kWh)**
# ```plaintext
# |                          Lifecycle GHG Emissions Comparison
# | Wind          █               10-15 g CO2/kWh
# | Hydroelectric ██              4-15 g CO2/kWh
# | Solar         ████            20-50 g CO2/kWh
# ```
#
# **Diagram: Land Use (Acres/MW)**
# ```plaintext
# | Land Use                                                   Acres per MW
# | Hydroelectric ██████████████████████████████████           High land disruption
# | Wind          ████████████                                Moderate; aligns dual-use land utilization.
# Solar MW like option ranges/re-analysis tech refined.
# ```
#
# Visualizations Apparent Model Metrics.!!-X--------------------EXTERNAL
#
# QUANT Automotive Analytics Flexible Renewable Graph.
# **Writer**
# **Comprehensive Report: Comparing Renewable Energy Sources (Solar, Wind, and Hydroelectric)**
#
# ---
#
# ### Executive Summary
# As global demand for clean energy grows, comparing renewable energy sources—solar, wind, and hydroelectric—on criteria such as energy efficiency, environmental impact, and costs is critical for informed decision-making. Each energy source offers unique advantages and trade-offs, making their optimal use largely dependent on geographic, economic, and ecological factors. This report provides a comparative analysis, supported by data, and offers actionable recommendations for region-specific implementation strategies.
#
# ---
#
# ### 1. Energy Efficiency Comparison
#
# **Key Insights:**
# - **Hydroelectric energy** is the most efficient renewable source, achieving energy conversion rates of **85%-95%,** owing to its minimal energy losses during operation.
# - **Wind energy** achieves an intermediate efficiency, with capacity factors ranging from **35%-45%**, dictated by wind patterns and turbine placement.
# - **Solar energy** demonstrates lower conversion efficiency, with typical photovoltaic panels achieving **15%-22%**, though advancements in solar technology promise future improvements.
#
# **Recommendation:**
# - **Hydroelectric and wind energy** are ideal for regions with abundant water bodies or consistent wind patterns. Solar energy, despite lower efficiency, remains essential in areas with high solar irradiance, particularly where other resources are unavailable.
#
# ---
#
# ### 2. Environmental Impact Comparison
#
# **Lifecycle Greenhouse Gas Emissions (g CO2-e/kWh):**
# - **Wind energy:** **10-15 g CO2/kWh** (lowest emissions)
# - **Hydroelectric:** **4-15 g CO2/kWh**, though emissions can increase in tropical reservoirs.
# - **Solar:** **20-50 g CO2/kWh** due to manufacturing and disposal processes.
#
# **Land Use:**
# - Hydroelectric power requires significant land disruption, often flooding large areas.
# - Wind energy requires **30-40 acres per MW**, which can often retain agricultural or other uses.
# - Solar installations use **10-20 acres per MW** but can be implemented on rooftops or other structures.
#
# **Wildlife/Ecosystem Disruption:**
# - Hydroelectric projects significantly alter aquatic ecosystems and fish migration patterns.
# - Wind turbines pose moderate risks to bird and bat populations, which can be mitigated.
# - Solar projects primarily disrupt land ecosystems but have a smaller overall ecosystem impact.
#
# **Recommendation:**
# - **Wind energy** is the most environmentally favorable option overall, with the lowest emissions and moderate land use. **Solar energy** is well-suited for urban and suburban environments, particularly when integrated with existing infrastructure. **Hydroelectric energy** should be reserved for areas where ecological risks are minimal and long-term benefits outweigh construction impacts.
#
# ---
#
# ### 3. Cost Comparison
#
# **Installation Costs (per kW):**
# - **Solar:** $850–$1,250 (utility-scale)
# - **Wind (Onshore):** $850–$1,600; **Wind (Offshore):** $2,500–$4,800
# - **Hydroelectric:** $1,500–$3,500
#
# **Levelized Cost of Energy (LCOE, per MWh):**
# - **Solar:** $24–$96
# - **Wind (Onshore):** $26–$50; **Wind (Offshore):** $60–$100
# - **Hydroelectric:** $30–$80
#
# **Recommendation:**
# - For regions with cost constraints, **onshore wind** and **utility-scale solar** are increasingly cost-competitive. **Hydroelectric projects**, while requiring significant initial investment, provide long-term cost efficiency, particularly in regions with favorable topography.
#
# ---
#
# ### 4. Implementation Recommendations
#
# **Optimal Scenarios for Implementation:**
# 1. **Solar Energy:**
#    - Best for arid or sunny regions, such as deserts or areas with high solar irradiance.
#    - Urban areas benefit from rooftop installations, reducing land use impact.
#    - Incorporate into decentralized energy systems for households and small communities.
#
# 2. **Wind Energy:**
#    - Coastal and plains areas are ideal due to consistent high-speed winds.
#    - Offshore wind farms offer large-scale opportunities for regions with extensive coastlines.
#    - Onshore wind farms can complement agricultural or grazing activities, maximizing land use.
#
# 3. **Hydroelectric Energy:**
#    - Suitable for regions with significant water resources and elevation changes.
#    - Ideal for large-scale, long-term energy projects in areas where ecological disruption is minimal.
#    - Use small-scale hydro systems where large dams are not feasible or environmentally prudent.
#
# ---
#
# ### 5. Conclusion
#
# All three renewable energy sources—solar, wind, and hydroelectric—play vital roles in the transition to a sustainable energy future. However, their optimal utilization depends on careful alignment with region-specific factors such as geography, climate, and infrastructure.
#
# - **Wind energy** emerges as a strong all-around option for its high efficiency, low emissions, and moderate land impact.
# - **Solar energy** is invaluable for decentralized systems and areas with high solar potential.
# - **Hydroelectric energy** offers unmatched efficiency and long-term cost-effectiveness but requires careful consideration of ecological impacts.
#
# **Final Recommendation:**
# Policymakers and energy planners should adopt a mixed renewable portfolio tailored to the unique characteristics of each region. Prioritizing renewable energy that aligns with local resources and sustainability goals will maximize economic, environmental, and social benefits.
#
# ---
#
# ### Supporting Data Visualizations
# (This section would include bar graphs, comparative tables, and charts as described in the analysis section, formatted for easy interpretation.)
# **Writer**
# **Comprehensive Report: Comparing Renewable Energy Sources (Solar, Wind, and Hydroelectric)**
#
# ---
#
# ### Executive Summary
# As global demand for clean energy grows, comparing renewable energy sources—solar, wind, and hydroelectric—on criteria such as energy efficiency, environmental impact, and costs is critical for informed decision-making. Each energy source offers unique advantages and trade-offs, making their optimal use largely dependent on geographic, economic, and ecological factors. This report provides a comparative analysis, supported by data, and offers actionable recommendations for region-specific implementation strategies.
#
# ---
#
# ### 1. Energy Efficiency Comparison
#
# **Key Insights:**
# - **Hydroelectric energy** is the most efficient renewable source, achieving energy conversion rates of **85%-95%,** owing to its minimal energy losses during operation.
# - **Wind energy** achieves an intermediate efficiency, with capacity factors ranging from **35%-45%**, dictated by wind patterns and turbine placement.
# - **Solar energy** demonstrates lower conversion efficiency, with typical photovoltaic panels achieving **15%-22%**, though advancements in solar technology promise future improvements.
#
# **Recommendation:**
# - **Hydroelectric and wind energy** are ideal for regions with abundant water bodies or consistent wind patterns. Solar energy, despite lower efficiency, remains essential in areas with high solar irradiance, particularly where other resources are unavailable.
#
# ---
#
# ### 2. Environmental Impact Comparison
#
# **Lifecycle Greenhouse Gas Emissions (g CO2-e/kWh):**
# - **Wind energy:** **10-15 g CO2/kWh** (lowest emissions)
# - **Hydroelectric:** **4-15 g CO2/kWh**, though emissions can increase in tropical reservoirs.
# - **Solar:** **20-50 g CO2/kWh** due to manufacturing and disposal processes.
#
# **Land Use:**
# - Hydroelectric power requires significant land disruption, often flooding large areas.
# - Wind energy requires **30-40 acres per MW**, which can often retain agricultural or other uses.
# - Solar installations use **10-20 acres per MW** but can be implemented on rooftops or other structures.
#
# **Wildlife/Ecosystem Disruption:**
# - Hydroelectric projects significantly alter aquatic ecosystems and fish migration patterns.
# - Wind turbines pose moderate risks to bird and bat populations, which can be mitigated.
# - Solar projects primarily disrupt land ecosystems but have a smaller overall ecosystem impact.
#
# **Recommendation:**
# - **Wind energy** is the most environmentally favorable option overall, with the lowest emissions and moderate land use. **Solar energy** is well-suited for urban and suburban environments, particularly when integrated with existing infrastructure. **Hydroelectric energy** should be reserved for areas where ecological risks are minimal and long-term benefits outweigh construction impacts.
#
# ---
#
# ### 3. Cost Comparison
#
# **Installation Costs (per kW):**
# - **Solar:** $850–$1,250 (utility-scale)
# - **Wind (Onshore):** $850–$1,600; **Wind (Offshore):** $2,500–$4,800
# - **Hydroelectric:** $1,500–$3,500
#
# **Levelized Cost of Energy (LCOE, per MWh):**
# - **Solar:** $24–$96
# - **Wind (Onshore):** $26–$50; **Wind (Offshore):** $60–$100
# - **Hydroelectric:** $30–$80
#
# **Recommendation:**
# - For regions with cost constraints, **onshore wind** and **utility-scale solar** are increasingly cost-competitive. **Hydroelectric projects**, while requiring significant initial investment, provide long-term cost efficiency, particularly in regions with favorable topography.
#
# ---
#
# ### 4. Implementation Recommendations
#
# **Optimal Scenarios for Implementation:**
# 1. **Solar Energy:**
#    - Best for arid or sunny regions, such as deserts or areas with high solar irradiance.
#    - Urban areas benefit from rooftop installations, reducing land use impact.
#    - Incorporate into decentralized energy systems for households and small communities.
#
# 2. **Wind Energy:**
#    - Coastal and plains areas are ideal due to consistent high-speed winds.
#    - Offshore wind farms offer large-scale opportunities for regions with extensive coastlines.
#    - Onshore wind farms can complement agricultural or grazing activities, maximizing land use.
#
# 3. **Hydroelectric Energy:**
#    - Suitable for regions with significant water resources and elevation changes.
#    - Ideal for large-scale, long-term energy projects in areas where ecological disruption is minimal.
#    - Use small-scale hydro systems where large dams are not feasible or environmentally prudent.
#
# ---
#
# ### 5. Conclusion
#
# All three renewable energy sources—solar, wind, and hydroelectric—play vital roles in the transition to a sustainable energy future. However, their optimal utilization depends on careful alignment with region-specific factors such as geography, climate, and infrastructure.
#
# - **Wind energy** emerges as a strong all-around option for its high efficiency, low emissions, and moderate land impact.
# - **Solar energy** is invaluable for decentralized systems and areas with high solar potential.
# - **Hydroelectric energy** offers unmatched efficiency and long-term cost-effectiveness but requires careful consideration of ecological impacts.
#
# **Final Recommendation:**
# Policymakers and energy planners should adopt a mixed renewable portfolio tailored to the unique characteristics of each region. Prioritizing renewable energy that aligns with local resources and sustainability goals will maximize economic, environmental, and social benefits.
#
# ---
#
# ### Supporting Data Visualizations
# (This section would include bar graphs, comparative tables, and charts as described in the analysis section, formatted for easy interpretation.)
#
# Comprehensive Report:
# Here is the comprehensive report comparing the energy efficiency, environmental impact, and costs of solar, wind, and hydroelectric energy sources, along with actionable recommendations for implementation:
#
# ---
#
# ### **Comprehensive Report: Renewable Energy Sources - Solar, Wind, and Hydroelectric**
#
# #### **Introduction**
# As the global transition toward sustainable energy intensifies, understanding the trade-offs between different renewable energy sources is critical. This report explores the energy efficiency, environmental impact, and financial implications of solar, wind, and hydroelectric energy sources, providing recommendations tailored for region-specific implementation.
#
# ---
#
# ### **1. Energy Efficiency**
#
# - **Hydroelectric energy** is the most efficient, with conversion rates of **85%-95%**, making it a top choice for consistent and large-scale energy generation.
# - **Wind energy** has an intermediate efficiency, with capacity factors of **35%-45%,** depending on wind availability and turbine design.
# - **Solar energy** has the lowest efficiency, with photovoltaic (PV) panels converting **15%-22%** of sunlight into electricity, although ongoing advancements in solar cell technology aim to improve this figure.
#
# **Key Insight:** Hydroelectric energy offers superior efficiency, while wind and solar remain more accessible for diverse geographic locations.
#
# ---
#
# ### **2. Environmental Impact**
#
# - **Greenhouse Gas Emissions** (lifecycle basis):
#   - Wind: **10-15 g CO2/kWh** (lowest emissions).
#   - Hydroelectric: **4-15 g CO2/kWh**, though methane emissions from reservoirs can increase this in tropical climates.
#   - Solar: **20-50 g CO2/kWh**, primarily from manufacturing processes.
#
# - **Land and Ecosystem Impacts**:
#   - Solar installations require **10-20 acres per MW**, but rooftop systems reduce land disruption.
#   - Wind turbines need **30-40 acres per MW**, often allowing dual land use (e.g., farming).
#   - Hydroelectric projects typically require substantial land and water resources, significantly altering river ecosystems and potentially displacing communities.
#
# - **Wildlife Disruption**:
#   - Wind turbines can impact bird and bat populations.
#   - Hydroelectric dams disrupt aquatic ecosystems and fish migration.
#   - Solar installations disturb soil and land ecosystems but have a smaller overall ecological footprint.
#
# **Key Insight:** Wind energy has the least cumulative environmental impact, while solar is ideal for urban integration. Hydroelectricity has the largest ecological implications but can provide immense benefits in the right geographic conditions.
#
# ---
#
# ### **3. Costs**
#
# - **Installation Costs** (per kW):
#   - Solar: $850–$1,250 (utility-scale).
#   - Wind (onshore): $850–$1,600; Wind (offshore): $2,500–$4,800.
#   - Hydroelectric: $1,500–$3,500.
#
# - **Levelized Cost of Energy (LCOE)** (per MWh):
#   - Solar: **$24–$96**.
#   - Wind (onshore): **$26–$50**; Wind (offshore): **$60–$100**.
#   - Hydroelectric: **$30–$80**.
#
# **Key Insight:** Wind and solar have become the most cost-competitive options, particularly in regions where installation is straightforward. Hydroelectricity, while requiring higher upfront costs, is cost-effective over the long term for large-scale energy production.
#
# ---
#
# ### **4. Recommendations for Implementation**
#
# **Solar Energy**:
# - Best suited for sunny regions with high solar irradiance (e.g., arid or desert regions).
# - Rooftop systems are invaluable for urban and suburban settings, reducing land use impact.
# - Effective in decentralized energy systems for homes, schools, and smaller communities.
#
# **Wind Energy**:
# - Ideal for coastal areas, plains, and locations with consistent wind patterns.
# - Offshore wind farms are a powerful option for countries with extensive coastlines.
# - Onshore installations provide opportunities for dual-use land (e.g., agriculture + energy).
#
# **Hydroelectric Energy**:
# - Best implemented in regions with abundant water resources and elevation changes.
# - Small-scale hydro systems are effective for rural, off-grid areas where large dams are unfeasible.
# - Large dams should focus on areas where ecological disruption is minimal and long-term benefits justify the initial environmental impact.
#
# ---
#
# ### **Conclusion**
#
# Each renewable energy source—solar, wind, and hydroelectric—comes with clear strengths and trade-offs. To build a sustainable and efficient energy future, each source should be implemented strategically based on regional resources and infrastructure:
#
# - **Wind energy** is the most environmentally friendly and cost-effective all-around option.
# - **Solar energy** is versatile and well-suited for distributed energy systems, especially in urban settings.
# - **Hydroelectric energy** provides unmatched efficiency and reliability but must be deployed cautiously to minimize ecological impact.
#
# Policymakers and energy developers should strive for a balanced, mixed portfolio of renewable energy sources to maximize energy generation while minimizing environmental and financial costs.
#
# ---
#
# If you would like to dive deeper into any of these aspects or see detailed visualizations, feel free to ask!
#
# Comprehensive Report:
# Here is the comprehensive report comparing the energy efficiency, environmental impact, and costs of solar, wind, and hydroelectric energy sources, along with actionable recommendations for implementation:
#
# ---
#
# ### **Comprehensive Report: Renewable Energy Sources - Solar, Wind, and Hydroelectric**
#
# #### **Introduction**
# As the global transition toward sustainable energy intensifies, understanding the trade-offs between different renewable energy sources is critical. This report explores the energy efficiency, environmental impact, and financial implications of solar, wind, and hydroelectric energy sources, providing recommendations tailored for region-specific implementation.
#
# ---
#
# ### **1. Energy Efficiency**
#
# - **Hydroelectric energy** is the most efficient, with conversion rates of **85%-95%**, making it a top choice for consistent and large-scale energy generation.
# - **Wind energy** has an intermediate efficiency, with capacity factors of **35%-45%,** depending on wind availability and turbine design.
# - **Solar energy** has the lowest efficiency, with photovoltaic (PV) panels converting **15%-22%** of sunlight into electricity, although ongoing advancements in solar cell technology aim to improve this figure.
#
# **Key Insight:** Hydroelectric energy offers superior efficiency, while wind and solar remain more accessible for diverse geographic locations.
#
# ---
#
# ### **2. Environmental Impact**
#
# - **Greenhouse Gas Emissions** (lifecycle basis):
#   - Wind: **10-15 g CO2/kWh** (lowest emissions).
#   - Hydroelectric: **4-15 g CO2/kWh**, though methane emissions from reservoirs can increase this in tropical climates.
#   - Solar: **20-50 g CO2/kWh**, primarily from manufacturing processes.
#
# - **Land and Ecosystem Impacts**:
#   - Solar installations require **10-20 acres per MW**, but rooftop systems reduce land disruption.
#   - Wind turbines need **30-40 acres per MW**, often allowing dual land use (e.g., farming).
#   - Hydroelectric projects typically require substantial land and water resources, significantly altering river ecosystems and potentially displacing communities.
#
# - **Wildlife Disruption**:
#   - Wind turbines can impact bird and bat populations.
#   - Hydroelectric dams disrupt aquatic ecosystems and fish migration.
#   - Solar installations disturb soil and land ecosystems but have a smaller overall ecological footprint.
#
# **Key Insight:** Wind energy has the least cumulative environmental impact, while solar is ideal for urban integration. Hydroelectricity has the largest ecological implications but can provide immense benefits in the right geographic conditions.
#
# ---
#
# ### **3. Costs**
#
# - **Installation Costs** (per kW):
#   - Solar: $850–$1,250 (utility-scale).
#   - Wind (onshore): $850–$1,600; Wind (offshore): $2,500–$4,800.
#   - Hydroelectric: $1,500–$3,500.
#
# - **Levelized Cost of Energy (LCOE)** (per MWh):
#   - Solar: **$24–$96**.
#   - Wind (onshore): **$26–$50**; Wind (offshore): **$60–$100**.
#   - Hydroelectric: **$30–$80**.
#
# **Key Insight:** Wind and solar have become the most cost-competitive options, particularly in regions where installation is straightforward. Hydroelectricity, while requiring higher upfront costs, is cost-effective over the long term for large-scale energy production.
#
# ---
#
# ### **4. Recommendations for Implementation**
#
# **Solar Energy**:
# - Best suited for sunny regions with high solar irradiance (e.g., arid or desert regions).
# - Rooftop systems are invaluable for urban and suburban settings, reducing land use impact.
# - Effective in decentralized energy systems for homes, schools, and smaller communities.
#
# **Wind Energy**:
# - Ideal for coastal areas, plains, and locations with consistent wind patterns.
# - Offshore wind farms are a powerful option for countries with extensive coastlines.
# - Onshore installations provide opportunities for dual-use land (e.g., agriculture + energy).
#
# **Hydroelectric Energy**:
# - Best implemented in regions with abundant water resources and elevation changes.
# - Small-scale hydro systems are effective for rural, off-grid areas where large dams are unfeasible.
# - Large dams should focus on areas where ecological disruption is minimal and long-term benefits justify the initial environmental impact.
#
# ---
#
# ### **Conclusion**
#
# Each renewable energy source—solar, wind, and hydroelectric—comes with clear strengths and trade-offs. To build a sustainable and efficient energy future, each source should be implemented strategically based on regional resources and infrastructure:
#
# - **Wind energy** is the most environmentally friendly and cost-effective all-around option.
# - **Solar energy** is versatile and well-suited for distributed energy systems, especially in urban settings.
# - **Hydroelectric energy** provides unmatched efficiency and reliability but must be deployed cautiously to minimize ecological impact.
#
# Policymakers and energy developers should strive for a balanced, mixed portfolio of renewable energy sources to maximize energy generation while minimizing environmental and financial costs.
#
# ---
#
# If you would like to dive deeper into any of these aspects or see detailed visualizations, feel free to ask!

# %% [markdown]
# ---
#
# # Pattern Comparison Summary
#
# | Pattern | Best For | Coordination Style | Output Type |
# |---------|----------|-------------------|-------------|
# | **Sequential** | Pipelines, step-by-step processing | Linear flow | Single refined result |
# | **Concurrent** | Multiple perspectives, brainstorming | Parallel execution | Multiple diverse results |
# | **Group Chat** | Collaborative discussions, meetings | Conversational | Consensus or discussion summary |
# | **Handoff** | Expert delegation, customer support | Context-based transfer | Specialized resolution |
# | **Magentic** | Complex projects, adaptive workflows | Dynamic coordination | Comprehensive solution |
#
# ## Key Benefits of Multi-Agent Orchestration
#
# 1. **Specialization**: Each agent can focus on their area of expertise
# 2. **Scalability**: Easy to add new agents or modify workflows
# 3. **Flexibility**: Different patterns for different use cases
# 4. **Robustness**: Multiple agents provide redundancy and error checking
# 5. **Unified Interface**: Same API across all orchestration patterns
#
# ## Choosing the Right Pattern
#
# - **Sequential**: When each step depends on the previous one
# - **Concurrent**: When you need diverse perspectives or quick parallel processing
# - **Group Chat**: When collaborative discussion adds value
# - **Handoff**: When different expertise is needed based on context
# - **Magentic**: When the task is complex and requires adaptive coordination
#
# ## Next Steps
#
# 1. Experiment with different patterns for your use cases
# 2. Customize agent instructions for your domain
# 3. Implement error handling and retry logic
# 4. Monitor and optimize agent performance
# 5. Consider hybrid approaches combining multiple patterns
#
# For more detailed documentation, visit the [Microsoft Learn site for Semantic Kernel Multi-agent Orchestration](https://learn.microsoft.com/en-us/semantic-kernel/frameworks/agent/agent-orchestration/).
